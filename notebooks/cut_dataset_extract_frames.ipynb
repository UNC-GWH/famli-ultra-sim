# %%
import os
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go
import SimpleITK as sitk
import numpy as np

# %%
df_clarius = pd.read_parquet('/mnt/raid/C1_ML_Analysis/test_output/classification/c2_instance_table_clarius_resampled_file_path_extract_frames_blind_sweeps_merged.parquet')

# %%
df_clarius.hist(column='pred_class')
# Out:
# array([[<Axes: title={'center': 'pred_class'}>]], dtype=object)

# %%
df_sonosite = pd.read_parquet('/mnt/raid/C1_ML_Analysis/test_output/classification/c1_instance_table_sonosite_resampled_file_path_extract_frames_blind_sweeps_merged.parquet')

# %%
df_sonosite.hist(column='pred_class')
# Out:
# array([[<Axes: title={'center': 'pred_class'}>]], dtype=object)

# %%
df_butterfly = pd.read_parquet('/mnt/raid/C1_ML_Analysis/test_output/classification/extract_frames_blind_sweeps_butterfly_merged.parquet')

# %%
df_butterfly.hist(column='pred_class')
# Out:
# array([[<Axes: title={'center': 'pred_class'}>]], dtype=object)

# %%
df_voluson = pd.read_parquet('/mnt/raid/C1_ML_Analysis/test_output/classification/extract_frames_blind_sweeps_voluson_merged.parquet')

# %%
df_voluson.hist(column='pred_class')
# Out:
# array([[<Axes: title={'center': 'pred_class'}>]], dtype=object)

# %%
unique_classes = df_voluson['pred_class'].unique()

# %%
import random
random.shuffle(unique_classes)

# %%
unique_classes
# Out:
# array([ 2, 32, 27, 16, 24,  5,  7, 13, 30, 34, 22, 21, 18,  8, 20, 29,  1,
#        23, 12, 26,  4,  0,  3,  6, 25, 28, 33, 17, 15, 11, 14, 10, 31, 19])

# %%
study_ids = pd.concat([df_clarius['PID'], df_sonosite['PID'], df_butterfly['PID'], df_voluson['PID']]).unique()

# %%
df_study_ids = pd.DataFrame(study_ids, columns=['PID'])
df_study_ids.to_csv('/mnt/raid/C1_ML_Analysis/cut_multi_dataset/study_ids.csv', index=False)
