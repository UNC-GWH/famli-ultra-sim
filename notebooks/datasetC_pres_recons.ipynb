# %%
import pandas as pd
import os

# %%
# df = pd.read_csv('/mnt/famli_netapp_shared/C1_ML_Analysis/famli_ml_lists/AnalysisLists/Ben/current_version/C_dataset_analysis.csv')
df = pd.read_csv('/mnt/famli_netapp_shared/C1_ML_Analysis/famli_ml_lists/AnalysisLists/Juan/C_dataset_analysis_protocoltagsonly.csv')
df.columns
# Out:
# /mnt/raid/home/jprieto/tmp/ipykernel_352021/1204519497.py:2: DtypeWarning: Columns (12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/mnt/famli_netapp_shared/C1_ML_Analysis/famli_ml_lists/AnalysisLists/Juan/C_dataset_analysis_protocoltagsonly.csv')
# Index(['file_name', 'manufacturer', 'model', 'study_id', 'site', 'file_path',
#        'tag', 'pid', 'studydate', 'studydate_dt', 'episode_edd', 'session_id',
#        'pat_mrn_id', 'n_rows', 'n_columns', 'n_frames', 'spacing_x',
#        'spacing_y', 'ga_boe', 'ga_expert', 'famli_edd_source',
#        'famli_edd_source_detail', 'is_anchor', 'fetal_presentation',
#        'fetal_presentation_str', 'efw_Hadlock_IV', 'twin', 'us_dvp_crf',
#        'us_dvp_sr', 'episode_edd_dt', 'PregnancyID', 'twin_gt', 'singleton_gt',
#        'efw_gt'],
#       dtype='object')

# %%
df = df[df['tag'].isin(["L1", "L0", "M", "R0", "R1", "C1", "C2", "C3", "C4"])]

# %%
df = df.query('ga_boe > 230')

# %%
df[['study_id', 'fetal_presentation_str']].drop_duplicates().groupby('fetal_presentation_str').describe()
# Out:
#                        study_id
#                           count unique             top freq
# fetal_presentation_str
# Breech                       34     34  FAM-025-0447-5    1
# Cephalic                    637    637  FAM-025-0313-7    1
# Transverse                    8      8  FAM-025-0626-2    1
# Variable / NA                 4      4  FAM-025-1813-1    1

# %%
df.to_csv('/mnt/famli_netapp_shared/C1_ML_Analysis/famli_ml_lists/AnalysisLists/Juan/C_dataset_analysis_protocoltagsonly_gaboe230.csv', index=False)

# %%
df.groupby('model').describe()

#README!!!!!!!!!!!
# This dataframe was filtered using ->
# python /mnt/famli_netapp_shared/C1_ML_Analysis/src/famli-ultra-sim/filter_dataframe.py --csv /mnt/famli_netapp_shared/C1_ML_Analysis/famli_ml_lists/AnalysisLists/Juan/C_dataset_analysis_protocoltagsonly_gaboe230.csv --out /mnt/famli_netapp_shared/C1_ML_Analysis/famli_ml_lists/AnalysisLists/Juan/C_dataset_analysis_protocoltagsonly_gaboe230.csv_
# Out:
#               episode_edd                                                    \
#                     count          mean           std        min        25%
# model
# C3HD                608.0  5.712909e+06  2.923182e+06  1012021.0  3112021.0
# LOGIQeCine          187.0  6.473198e+06  2.750248e+06  2132021.0  4102022.0
# Turbo              1992.0  8.853556e+06  3.831264e+06  1012020.0  5192021.0
# Unnamed Probe         1.0  5.232021e+06           NaN  5232021.0  5232021.0
# V830               1805.0  7.227988e+06  3.647548e+06  1042022.0  4032021.0
# Voluson S          2083.0  6.321478e+06  3.948562e+06  1012020.0  3032020.0
# iQ Probe            972.0  7.734027e+06  3.672862e+06  1052022.0  4082022.0
# iQ+ Probe           930.0  9.897775e+06  1.520015e+06  5212022.0  9042022.0
#
#                                                    n_rows             ...  \
#                       50%         75%         max   count       mean  ...
# ...

# %%
# df[['file_path']].to_csv('/mnt/famli_netapp_shared/C1_ML_Analysis/famli_ml_lists/AnalysisLists/Juan/C_dataset_analysis_protocoltagsonly_gaboe230_file_path.csv', index=False)

# %%
# df_c1 = pd.read_csv('/mnt/famli_netapp_shared/C1_ML_Analysis/CSV_files/C_dataset_analysis_protocoltagsonly_gaboe230_C1.csv')

# %%
# df_c1['file_path'] = df_c1['file_path'].str.replace('Groups/FAMLI/Restricted_access_data/Ultrasound/Dataset_C1/', 'Dataset_C1_masked_resampled_256_spc075/').str.replace('.dcm', '.nrrd')

# %%
# mount_point = '/mnt/famli_netapp_shared/C1_ML_Analysis'
# for idx, row in df_c1.iterrows():
    # source_file_path = os.path.join(mount_point, row['file_path'])
    # target_file_path = os.path.join(os.path.dirname(source_file_path), row['tag'] + ".nrrd")
    # if os.path.exists(source_file_path) and os.path.exists(target_file_path):
        # os.unlink(target_file_path)
    # if os.path.exists(source_file_path) and not os.path.exists(target_file_path):
        # source_file_name = os.path.basename(source_file_path)
        # print("os.symlink({source_file_name}, {target_file_path})".format(source_file_name=source_file_name, target_file_path=target_file_path))
        # os.symlink(source_file_name, target_file_path)
        # print("os.link({source_file_path}, {target_file_path})".format(source_file_path=source_file_path, target_file_path=target_file_path))
        # os.symlink(source_file_path, target_file_path)

# %%
# os.symlink("1.2.840.114340.3.8251017232192.3.20191011.100441.151964.4.nrrd", "/mnt/famli_netapp_shared/C1_ML_Analysis/Dataset_C1_masked_resampled_256_spc075/2019-10/FAM-025-0313-7_20191011_094447/C1.nrrd")

# %%
df = pd.read_csv('/mnt/famli_netapp_shared/C1_ML_Analysis/famli_ml_lists/AnalysisLists/Juan/C_dataset_analysis_protocoltagsonly_gaboe230.csv')

# %%
df.groupby('model').describe()
# Out:
#               episode_edd                                                    \
#                     count          mean           std        min        25%
# model
# C3HD                608.0  5.712909e+06  2.923182e+06  1012021.0  3112021.0
# LOGIQeCine          187.0  6.473198e+06  2.750248e+06  2132021.0  4102022.0
# Turbo              1992.0  8.853556e+06  3.831264e+06  1012020.0  5192021.0
# Unnamed Probe         1.0  5.232021e+06           NaN  5232021.0  5232021.0
# V830               1805.0  7.227988e+06  3.647548e+06  1042022.0  4032021.0
# Voluson S          2083.0  6.321478e+06  3.948562e+06  1012020.0  3032020.0
# iQ Probe            972.0  7.734027e+06  3.672862e+06  1052022.0  4082022.0
# iQ+ Probe           930.0  9.897775e+06  1.520015e+06  5212022.0  9042022.0
#
#                                                   pat_mrn_id                \
#                       50%         75%         max      count          mean
# model
# ...

# %%
df_iq_vol = df[df['model'].isin(['Voluson S', 'iQ Probe', 'iQ+ Probe', 'V830', 'LOGIQeCine'])]

# %%
df_iq_vol['study_id'].drop_duplicates()
# Out:
# 72      FAM-025-0453-5
# 117     FAM-025-0479-6
# 144     FAM-025-0488-7
# 199     FAM-025-0521-5
# 208     FAM-025-0523-5
#              ...
# 8452        UNC-1026-7
# 8479        UNC-1033-5
# 8506        UNC-1033-6
# 8533        UNC-1037-4
# 8560        UNC-1037-5
# Name: study_id, Length: 486, dtype: object

# %%
df_iq_vol.to_csv('/mnt/famli_netapp_shared/C1_ML_Analysis/famli_ml_lists/AnalysisLists/Juan/C_dataset_analysis_protocoltagsonly_gaboe230_ge_iq.csv', index=False)
