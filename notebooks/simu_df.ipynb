# %%
import pandas as pd
import plotly
import plotly.express as px
import os
import glob

# %%
df = pd.read_csv("/mnt/raid/C1_ML_Analysis/CSV_files/ALL_C2_cines_gt_ga_withmeta_20221031_butterfly_train.csv")
# Out:
# /mnt/raid/home/jprieto/tmp/ipykernel_2593257/4276483297.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/mnt/raid/C1_ML_Analysis/CSV_files/ALL_C2_cines_gt_ga_withmeta_20221031_butterfly_train.csv")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'tag', 'fetal_presentation_str', 'study_id', 'file_path',
#        'dvp_crf', 'fetal_presentation', 'study_instance_n', 'model',
#        'file_name', 'spacing_x', 'spacing_y', 'n_rows', 'n_columns',
#        'n_frames.1', 'session_id', 'n_frames', 'gatool_session',
#        'famli_session_id', 'ga_boe', 'ga_expert', 'famli_edd_source',
#        'famli_edd_source_detail', 'ga_absdiff', 'is_anchor', 'new_n_frames',
#        'new_n_frames.1', 'pid', 'ineligible', 'twin'],
#       dtype='object')

# %%
df
# Out:
#        Unnamed: 0    tag fetal_presentation_str        study_id  \
# 0              16    NaN               Cephalic      UNC-0529-1
# 1              17    NaN               Cephalic      UNC-0529-1
# 2              18  ASSBS               Cephalic      UNC-0529-1
# 3              19  ASSBS               Cephalic      UNC-0529-1
# 4              20  ASSBS               Cephalic      UNC-0529-1
# ...           ...    ...                    ...             ...
# 51350       97483     NL                 Breech  FAM-025-1348-1
# 51351       97484     NR                 Breech  FAM-025-1348-1
# 51352       97485    NC1                 Breech  FAM-025-1348-1
# 51353       97486    NC2                 Breech  FAM-025-1348-1
# 51354       97487    NC3                 Breech  FAM-025-1348-1
#
#                                                file_path dvp_crf  \
# 0      Dataset_C_masked_resampled_256_spc075/2020-11/...       7
# ...

# %%
df.query('n_frames >= 64 and n_frames < 400')
# Out:
#        Unnamed: 0    tag fetal_presentation_str        study_id  \
# 0              16    NaN               Cephalic      UNC-0529-1
# 1              17    NaN               Cephalic      UNC-0529-1
# 2              18  ASSBS               Cephalic      UNC-0529-1
# 3              19  ASSBS               Cephalic      UNC-0529-1
# 4              20  ASSBS               Cephalic      UNC-0529-1
# ...           ...    ...                    ...             ...
# 51319       97392    BPD                 Breech  FAM-025-1338-1
# 51341       97474     NM               Variable  FAM-025-1347-1
# 51344       97477    NC1               Variable  FAM-025-1347-1
# 51346       97479    NC3               Variable  FAM-025-1347-1
# 51348       97481    TCD                 Breech  FAM-025-1348-1
#
#                                                file_path dvp_crf  \
# 0      Dataset_C_masked_resampled_256_spc075/2020-11/...       7
# ...

# %%
fig = px.histogram(df, x="n_frames")

# %%
fig

# %%
df.query('n_frames > 1000')['file_path'].sample(n=1).values[0]
# Out:
# 'Dataset_C_masked_resampled_256_spc075/2019-03/FAM-202-0128-1_20190307_055710/4fae309e-63c9-4577-8798-73f25de250da.nrrd'
